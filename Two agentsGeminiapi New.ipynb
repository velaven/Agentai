# %%
#!pip install agentops
#!pip install autogen
# Out:
# Requirement already satisfied: agentops in c:\users\kavitha\anaconda3\lib\site-packages (0.4.21)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (3.13.2)
# Requirement already satisfied: httpx<0.29.0,>=0.24.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (0.28.1)
# Requirement already satisfied: opentelemetry-api>1.29.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>1.29.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (1.42.1)
# Requirement already satisfied: opentelemetry-instrumentation>=0.50b0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (0.63b1)
# Requirement already satisfied: opentelemetry-sdk>1.29.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.50b0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (0.63b1)
# Requirement already satisfied: ordered-set<5.0.0,>=4.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (4.1.0)
# Requirement already satisfied: packaging<25.0,>=21.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (24.2)
# Requirement already satisfied: psutil<7.0.1,>=5.9.8 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (7.0.0)
# Requirement already satisfied: pyyaml<7.0,>=5.3 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (2.32.5)
# Requirement already satisfied: termcolor<2.5.0,>=2.3.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (2.4.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from agentops) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\kavitha\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->agentops) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\kavitha\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->agentops) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kavitha\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->agentops) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kavitha\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->agentops) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kavitha\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->agentops) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kavitha\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->agentops) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kavitha\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.0->agentops) (1.22.0)
# Requirement already satisfied: anyio in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<0.29.0,>=0.24.0->agentops) (4.10.0)
# Requirement already satisfied: certifi in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<0.29.0,>=0.24.0->agentops) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<0.29.0,>=0.24.0->agentops) (1.0.9)
# Requirement already satisfied: idna in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<0.29.0,>=0.24.0->agentops) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\kavitha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29.0,>=0.24.0->agentops) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->agentops) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->agentops) (2.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kavitha\anaconda3\lib\site-packages (from opentelemetry-api>1.29.0->agentops) (4.15.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\kavitha\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>1.29.0->agentops) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in c:\users\kavitha\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>1.29.0->agentops) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in c:\users\kavitha\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>1.29.0->agentops) (1.42.1)
# Requirement already satisfied: protobuf<7.0,>=5.0 in c:\users\kavitha\anaconda3\lib\site-packages (from opentelemetry-proto==1.42.1->opentelemetry-exporter-otlp-proto-http>1.29.0->agentops) (6.33.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kavitha\anaconda3\lib\site-packages (from anyio->httpx<0.29.0,>=0.24.0->agentops) (1.3.0)
# Requirement already satisfied: autogen in c:\users\kavitha\anaconda3\lib\site-packages (0.13.3)
# Requirement already satisfied: ag2==0.13.3 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen) (0.13.3)
# Requirement already satisfied: anyio<5.0.0,>=4.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (4.10.0)
# Requirement already satisfied: fast-depends<4.0.0,>=3.0.8 in c:\users\kavitha\anaconda3\lib\site-packages (from fast-depends[pydantic]<4.0.0,>=3.0.8->ag2==0.13.3->autogen) (3.0.8)
# Requirement already satisfied: httpx<1,>=0.28.1 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (0.28.1)
# Requirement already satisfied: packaging in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (24.2)
# Requirement already satisfied: pydantic<3,>=2.6.1 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (2.12.4)
# Requirement already satisfied: python-dotenv in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (1.2.2)
# Requirement already satisfied: pyyaml>=6.0.2 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (6.0.3)
# Requirement already satisfied: termcolor in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (2.4.0)
# Requirement already satisfied: tiktoken in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.13.3->autogen) (0.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\kavitha\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.0.0->ag2==0.13.3->autogen) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kavitha\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.0.0->ag2==0.13.3->autogen) (1.3.0)
# Requirement already satisfied: typing-extensions!=4.12.1 in c:\users\kavitha\anaconda3\lib\site-packages (from fast-depends<4.0.0,>=3.0.8->fast-depends[pydantic]<4.0.0,>=3.0.8->ag2==0.13.3->autogen) (4.15.0)
# Requirement already satisfied: certifi in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<1,>=0.28.1->ag2==0.13.3->autogen) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<1,>=0.28.1->ag2==0.13.3->autogen) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kavitha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.28.1->ag2==0.13.3->autogen) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->ag2==0.13.3->autogen) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->ag2==0.13.3->autogen) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->ag2==0.13.3->autogen) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\kavitha\anaconda3\lib\site-packages (from tiktoken->ag2==0.13.3->autogen) (2025.9.1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\kavitha\anaconda3\lib\site-packages (from tiktoken->ag2==0.13.3->autogen) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kavitha\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken->ag2==0.13.3->autogen) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kavitha\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken->ag2==0.13.3->autogen) (2.5.0)

# %%
import autogen_agentchat
print('autogen-agentchat:', autogen_agentchat.__version__)
# Out:
# autogen-agentchat: 0.4.3

# %%
import autogen_ext
print('autogen-ext:', autogen_ext.__version__)
# Out:
# autogen-ext: 0.4.3

# %%
import google.generativeai as genai
print('google.generativeai:', genai.__version__)
# Out:
# google.generativeai: 0.8.4

# %%
# !pip install autogen-agentchat[gemini]~=0.2
# !pip install ag2[gemini]
# !pip install chromadb==0.5.1
# !pip install google-generativeai==0.8.4
# !pip install vertexai==1.71.1
# !pip install ag2==0.7.3
# !pip install autogen-agentchat==0.4.3
#python==3.11.11
# Out:
# Requirement already satisfied: autogen-agentchat~=0.2 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-agentchat[gemini]~=0.2) (0.4.3)
# Requirement already satisfied: autogen-core==0.4.3 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (0.4.3)
# Requirement already satisfied: jsonref~=1.1.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (1.42.1)
# Requirement already satisfied: pillow>=11.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (12.0.0)
# Collecting protobuf~=4.25.1 (from autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2)
#   Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (2.12.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.3->autogen-agentchat~=0.2->autogen-agentchat[gemini]~=0.2) (0.4.2)
# Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.6
#     Uninstalling protobuf-6.33.6:
#       Successfully uninstalled protobuf-6.33.6
# Successfully installed protobuf-4.25.9
# WARNING: autogen-agentchat 0.4.3 does not provide the extra 'gemini'
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\KAVITHA\anaconda3\Lib\site-packages\google\~%pb'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-exporter-otlp-proto-common==1.41.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-proto==1.41.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-sdk~=1.41.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-proto 1.42.1 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 4.25.9 which is incompatible.
# Requirement already satisfied: ag2[gemini] in c:\users\kavitha\anaconda3\lib\site-packages (0.13.3)
# Requirement already satisfied: anyio<5.0.0,>=4.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (4.10.0)
# Requirement already satisfied: fast-depends<4.0.0,>=3.0.8 in c:\users\kavitha\anaconda3\lib\site-packages (from fast-depends[pydantic]<4.0.0,>=3.0.8->ag2[gemini]) (3.0.8)
# Requirement already satisfied: httpx<1,>=0.28.1 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (0.28.1)
# Requirement already satisfied: packaging in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (24.2)
# Requirement already satisfied: pydantic<3,>=2.6.1 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (2.12.4)
# Requirement already satisfied: python-dotenv in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (1.2.2)
# Requirement already satisfied: pyyaml>=6.0.2 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (6.0.3)
# Requirement already satisfied: termcolor in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (2.4.0)
# Requirement already satisfied: tiktoken in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (0.12.0)
# Requirement already satisfied: google-api-core in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (2.30.0)
# Requirement already satisfied: google-auth in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (2.49.0)
# Requirement already satisfied: google-cloud-aiplatform in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (1.71.1)
# Requirement already satisfied: google-genai<2.0,>=1.20.0 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (1.73.1)
# Requirement already satisfied: jsonschema in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (4.25.0)
# Requirement already satisfied: pillow in c:\users\kavitha\anaconda3\lib\site-packages (from ag2[gemini]) (12.0.0)
# Requirement already satisfied: idna>=2.8 in c:\users\kavitha\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.0.0->ag2[gemini]) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kavitha\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.0.0->ag2[gemini]) (1.3.0)
# Requirement already satisfied: typing-extensions!=4.12.1 in c:\users\kavitha\anaconda3\lib\site-packages (from fast-depends<4.0.0,>=3.0.8->fast-depends[pydantic]<4.0.0,>=3.0.8->ag2[gemini]) (4.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-genai<2.0,>=1.20.0->ag2[gemini]) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-genai<2.0,>=1.20.0->ag2[gemini]) (8.5.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-genai<2.0,>=1.20.0->ag2[gemini]) (14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-genai<2.0,>=1.20.0->ag2[gemini]) (1.9.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth->ag2[gemini]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth->ag2[gemini]) (46.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth->ag2[gemini]) (4.9.1)
# Requirement already satisfied: certifi in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<1,>=0.28.1->ag2[gemini]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<1,>=0.28.1->ag2[gemini]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kavitha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.28.1->ag2[gemini]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->ag2[gemini]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->ag2[gemini]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->ag2[gemini]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0,>=1.20.0->ag2[gemini]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0,>=1.20.0->ag2[gemini]) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kavitha\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth->ag2[gemini]) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth->ag2[gemini]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kavitha\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth->ag2[gemini]) (2.23)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core->ag2[gemini]) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core->ag2[gemini]) (4.25.9)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core->ag2[gemini]) (1.27.1)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform->ag2[gemini]) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform->ag2[gemini]) (3.41.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform->ag2[gemini]) (1.17.0)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform->ag2[gemini]) (2.1.2)
# Requirement already satisfied: docstring-parser<1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform->ag2[gemini]) (0.18.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->ag2[gemini]) (1.78.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform->ag2[gemini]) (1.71.2)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->ag2[gemini]) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->ag2[gemini]) (2.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->ag2[gemini]) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->ag2[gemini]) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform->ag2[gemini]) (1.8.0)
# Collecting protobuf<7.0.0,>=4.25.8 (from google-api-core->ag2[gemini])
#   Using cached protobuf-5.29.6-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\kavitha\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->ag2[gemini]) (1.17.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\kavitha\anaconda3\lib\site-packages (from shapely<3.0.0dev->google-cloud-aiplatform->ag2[gemini]) (2.3.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kavitha\anaconda3\lib\site-packages (from jsonschema->ag2[gemini]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kavitha\anaconda3\lib\site-packages (from jsonschema->ag2[gemini]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kavitha\anaconda3\lib\site-packages (from jsonschema->ag2[gemini]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kavitha\anaconda3\lib\site-packages (from jsonschema->ag2[gemini]) (0.28.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\kavitha\anaconda3\lib\site-packages (from tiktoken->ag2[gemini]) (2025.9.1)
# Using cached protobuf-5.29.6-cp310-abi3-win_amd64.whl (435 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.9
#     Uninstalling protobuf-4.25.9:
#       Successfully uninstalled protobuf-4.25.9
# Successfully installed protobuf-5.29.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogen-core 0.4.3 requires protobuf~=4.25.1, but you have protobuf 5.29.6 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-exporter-otlp-proto-common==1.41.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-proto==1.41.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-sdk~=1.41.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# Collecting chromadb==0.5.1
#   Using cached chromadb-0.5.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: build>=1.0.3 in c:\users\kavitha\anaconda3\lib\site-packages (from chromadb==0.5.1) (1.4.3)
# Requirement already satisfied: requests>=2.28 in c:\users\kavitha\anaconda3\lib\site-packages (from chromadb==0.5.1) (2.32.5)
# Requirement already satisfied: pydantic>=1.9 in c:\users\kavitha\anaconda3\lib\site-packages (from chromadb==0.5.1) (2.12.4)
# Collecting chroma-hnswlib==0.7.3 (from chromadb==0.5.1)
#   Using cached chroma-hnswlib-0.7.3.tar.gz (31 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\kavitha\anaconda3\lib\site-packages (from chromadb==0.5.1) (0.135.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\kavitha\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb==0.5.1) (0.44.0)
# Collecting numpy<2.0.0,>=1.22.5 (from chromadb==0.5.1)
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Preparing metadata (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [21 lines of output]
#   + C:\Users\KAVITHA\anaconda3\python.exe C:\Users\KAVITHA\AppData\Local\Temp\pip-install-_mvf2cs3\numpy_8adff6ac53ba4609b3905c601dcaad76\vendored-meson\meson\meson.py setup C:\Users\KAVITHA\AppData\Local\Temp\pip-install-_mvf2cs3\numpy_8adff6ac53ba4609b3905c601dcaad76 C:\Users\KAVITHA\AppData\Local\Temp\pip-install-_mvf2cs3\numpy_8adff6ac53ba4609b3905c601dcaad76\.mesonpy-ubl7ztwo -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --native-file=C:\Users\KAVITHA\AppData\Local\Temp\pip-install-_mvf2cs3\numpy_8adff6ac53ba4609b3905c601dcaad76\.mesonpy-ubl7ztwo\meson-python-native-file.ini
#   The Meson build system
#   Version: 1.2.99
#   Source dir: C:\Users\KAVITHA\AppData\Local\Temp\pip-install-_mvf2cs3\numpy_8adff6ac53ba4609b3905c601dcaad76
#   Build dir: C:\Users\KAVITHA\AppData\Local\Temp\pip-install-_mvf2cs3\numpy_8adff6ac53ba4609b3905c601dcaad76\.mesonpy-ubl7ztwo
#   Build type: native build
#   Project name: NumPy
#   Project version: 1.26.4
#   WARNING: Failed to activate VS environment: Could not find C:\Program Files (x86)\Microsoft Visual Studio\Installer\vswhere.exe
#
#   ..\meson.build:1:0: ERROR: Unknown compiler(s): [['icl'], ['cl'], ['cc'], ['gcc'], ['clang'], ['clang-cl'], ['pgcc']]
#   The following exception(s) were encountered:
#   Running `icl ""` gave "[WinError 2] The system cannot find the file specified"
#   Running `cl /?` gave "[WinError 2] The system cannot find the file specified"
#   Running `cc --version` gave "[WinError 2] The system cannot find the file specified"
#   Running `gcc --version` gave "[WinError 2] The system cannot find the file specified"
#   Running `clang --version` gave "[WinError 2] The system cannot find the file specified"
#   Running `clang-cl /?` gave "[WinError 2] The system cannot find the file specified"
#   Running `pgcc --version` gave "[WinError 2] The system cannot find the file specified"
#
#   A full log can be found at C:\Users\KAVITHA\AppData\Local\Temp\pip-install-_mvf2cs3\numpy_8adff6ac53ba4609b3905c601dcaad76\.mesonpy-ubl7ztwo\meson-logs\meson-log.txt
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# numpy
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: google-generativeai==0.8.4 in c:\users\kavitha\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (2.30.0)
# Requirement already satisfied: google-api-python-client in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (2.192.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (2.49.0)
# Requirement already satisfied: protobuf in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (5.29.6)
# Requirement already satisfied: pydantic in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (2.12.4)
# Requirement already satisfied: tqdm in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\kavitha\anaconda3\lib\site-packages (from google-generativeai==0.8.4) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai==0.8.4) (1.27.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core->google-generativeai==0.8.4) (1.73.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core->google-generativeai==0.8.4) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai==0.8.4) (1.78.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai==0.8.4) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai==0.8.4) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai==0.8.4) (46.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai==0.8.4) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai==0.8.4) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai==0.8.4) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai==0.8.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai==0.8.4) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kavitha\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google-generativeai==0.8.4) (0.6.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai==0.8.4) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kavitha\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai==0.8.4) (2.23)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai==0.8.4) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai==0.8.4) (0.3.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai==0.8.4) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\kavitha\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai==0.8.4) (3.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic->google-generativeai==0.8.4) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic->google-generativeai==0.8.4) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic->google-generativeai==0.8.4) (0.4.2)
# Requirement already satisfied: colorama in c:\users\kavitha\anaconda3\lib\site-packages (from tqdm->google-generativeai==0.8.4) (0.4.6)
# Requirement already satisfied: vertexai==1.71.1 in c:\users\kavitha\anaconda3\lib\site-packages (1.71.1)
# Requirement already satisfied: google-cloud-aiplatform==1.71.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.71.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.30.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.49.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.27.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (5.29.6)
# Requirement already satisfied: packaging>=14.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (3.41.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.17.0)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.1.2)
# Requirement already satisfied: pydantic<3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.12.4)
# Requirement already satisfied: docstring-parser<1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (0.18.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.73.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.78.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (46.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kavitha\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\kavitha\anaconda3\lib\site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.8.0)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\kavitha\anaconda3\lib\site-packages (from grpcio<2.0.0,>=1.33.2->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\kavitha\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kavitha\anaconda3\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\kavitha\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (0.6.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\kavitha\anaconda3\lib\site-packages (from shapely<3.0.0dev->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.3.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\kavitha\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform==1.71.1->google-cloud-aiplatform[all]==1.71.1->vertexai==1.71.1) (2.23)
# WARNING: google-cloud-aiplatform 1.71.1 does not provide the extra 'all'
# Collecting ag2==0.7.3
#   Using cached ag2-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pyautogen==0.7.3 in c:\users\kavitha\anaconda3\lib\site-packages (from ag2==0.7.3) (0.7.3)
# Requirement already satisfied: asyncer==0.0.8 in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (0.0.8)
# Requirement already satisfied: diskcache in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (5.6.3)
# Requirement already satisfied: docker in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (7.1.0)
# Collecting fast-depends<3,>=2.4.12 (from pyautogen==0.7.3->ag2==0.7.3)
#   Using cached fast_depends-2.4.12-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (2.3.5)
# Requirement already satisfied: openai>=1.58 in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (2.31.0)
# Requirement already satisfied: packaging in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (24.2)
# Requirement already satisfied: pydantic<3,>=2.6.1 in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (2.12.4)
# Requirement already satisfied: python-dotenv in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (1.2.2)
# Requirement already satisfied: termcolor in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (2.4.0)
# Requirement already satisfied: tiktoken in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (0.12.0)
# Requirement already satisfied: websockets<15,>=14 in c:\users\kavitha\anaconda3\lib\site-packages (from pyautogen==0.7.3->ag2==0.7.3) (14.2)
# Requirement already satisfied: anyio<5.0,>=3.4.0 in c:\users\kavitha\anaconda3\lib\site-packages (from asyncer==0.0.8->pyautogen==0.7.3->ag2==0.7.3) (4.10.0)
# Requirement already satisfied: idna>=2.8 in c:\users\kavitha\anaconda3\lib\site-packages (from anyio<5.0,>=3.4.0->asyncer==0.0.8->pyautogen==0.7.3->ag2==0.7.3) (3.11)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kavitha\anaconda3\lib\site-packages (from anyio<5.0,>=3.4.0->asyncer==0.0.8->pyautogen==0.7.3->ag2==0.7.3) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->pyautogen==0.7.3->ag2==0.7.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->pyautogen==0.7.3->ag2==0.7.3) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->pyautogen==0.7.3->ag2==0.7.3) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3,>=2.6.1->pyautogen==0.7.3->ag2==0.7.3) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kavitha\anaconda3\lib\site-packages (from openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kavitha\anaconda3\lib\site-packages (from openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\kavitha\anaconda3\lib\site-packages (from openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (0.13.0)
# Requirement already satisfied: tqdm>4 in c:\users\kavitha\anaconda3\lib\site-packages (from openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (4.67.1)
# Requirement already satisfied: certifi in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\kavitha\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\kavitha\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (0.16.0)
# Requirement already satisfied: colorama in c:\users\kavitha\anaconda3\lib\site-packages (from tqdm>4->openai>=1.58->pyautogen==0.7.3->ag2==0.7.3) (0.4.6)
# Requirement already satisfied: pywin32>=304 in c:\users\kavitha\anaconda3\lib\site-packages (from docker->pyautogen==0.7.3->ag2==0.7.3) (311)
# Requirement already satisfied: requests>=2.26.0 in c:\users\kavitha\anaconda3\lib\site-packages (from docker->pyautogen==0.7.3->ag2==0.7.3) (2.32.5)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\kavitha\anaconda3\lib\site-packages (from docker->pyautogen==0.7.3->ag2==0.7.3) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kavitha\anaconda3\lib\site-packages (from requests>=2.26.0->docker->pyautogen==0.7.3->ag2==0.7.3) (3.4.4)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\kavitha\anaconda3\lib\site-packages (from tiktoken->pyautogen==0.7.3->ag2==0.7.3) (2025.9.1)
# Using cached ag2-0.7.3-py3-none-any.whl (13 kB)
# Using cached fast_depends-2.4.12-py3-none-any.whl (17 kB)
# Installing collected packages: fast-depends, ag2
#
#   Attempting uninstall: fast-depends
#
#     Found existing installation: fast-depends 3.0.8
#
#     Uninstalling fast-depends-3.0.8:
#
#       Successfully uninstalled fast-depends-3.0.8
#
#   Attempting uninstall: ag2
#
#     Found existing installation: ag2 0.13.3
#
#     Uninstalling ag2-0.13.3:
#
#    -------------------- ------------------- 1/2 [ag2]
#       Successfully uninstalled ag2-0.13.3
#    -------------------- ------------------- 1/2 [ag2]
#    -------------------- ------------------- 1/2 [ag2]
#    ---------------------------------------- 2/2 [ag2]
#
# Successfully installed ag2-0.7.3 fast-depends-2.4.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogen 0.13.3 requires ag2==0.13.3, but you have ag2 0.7.3 which is incompatible.
# Requirement already satisfied: autogen-agentchat==0.4.3 in c:\users\kavitha\anaconda3\lib\site-packages (0.4.3)
# Requirement already satisfied: autogen-core==0.4.3 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-agentchat==0.4.3) (0.4.3)
# Requirement already satisfied: jsonref~=1.1.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat==0.4.3) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat==0.4.3) (1.42.1)
# Requirement already satisfied: pillow>=11.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat==0.4.3) (12.0.0)
# Collecting protobuf~=4.25.1 (from autogen-core==0.4.3->autogen-agentchat==0.4.3)
#   Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat==0.4.3) (2.12.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\kavitha\anaconda3\lib\site-packages (from autogen-core==0.4.3->autogen-agentchat==0.4.3) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.3->autogen-agentchat==0.4.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.3->autogen-agentchat==0.4.3) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kavitha\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.4.3->autogen-agentchat==0.4.3) (0.4.2)
# Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl (413 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# Successfully installed protobuf-4.25.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-exporter-otlp-proto-common==1.41.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-proto==1.41.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-grpc 1.41.0 requires opentelemetry-sdk~=1.41.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-proto 1.42.1 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 4.25.9 which is incompatible.
